# %%
import pandas as pd
import matplotlib.pyplot as plt


# Load the CSV file
df = pd.read_csv('node_failure_experiment.csv')
# convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# create new columns and put delta time in them from the previous row
df['delta_time'] = df['timestamp'].diff().dt.total_seconds()

# Display the DataFrame
df
# Out:
#   phase               timestamp  \
# 0  INFO 2025-07-31 09:39:23.608
# 1    2a 2025-07-31 09:39:33.882
# 2    3a 2025-07-31 09:45:06.707
# 3    3b 2025-07-31 09:45:07.990
# 4    3c 2025-07-31 09:45:08.116
#
#                                             note  delta_time
# 0       Pod initially scheduled to decice-worker         NaN
# 1  Node decice-worker stopped (simulate failure)      10.274
# 2    New pod test-app-7c649c7fdc-mq7l5 scheduled     332.825
# 3                  New pod entered Running phase       1.283
# 4                           New pod became Ready       0.126

# %%
import pandas as pd


# Load the CSV file
df = pd.read_csv('node_failure_experiment-1.csv')
# convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# create new columns and put delta time in them from the previous row
df['delta_time'] = df['timestamp'].diff().dt.total_seconds()

# Display the DataFrame
df
# Out:
#   phase               timestamp  \
# 0  INFO 2025-09-23 13:54:41.528
# 1    2a 2025-09-23 13:54:41.691
# 2    3a 2025-09-23 14:00:18.544
# 3    3b 2025-09-23 14:00:20.803
# 4    3c 2025-09-23 14:00:20.879
#
#                                                 note  delta_time
# 0          Pod initially scheduled to acnode10.e4red         NaN
# 1  kubelet/containerd stopped locally on acnode10...       0.163
# 2  New pod test-app-5cbcc7d5f4-49jr7 scheduled on...     336.853
# 3    New pod entered Running phase on acnode11.e4red       2.259
# 4             New pod became Ready on acnode11.e4red       0.076

# %%
import pandas as pd


# Load the CSV file
df = pd.read_csv('node_failure_experiment-2.csv')
# convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# create new columns and put delta time in them from the previous row
df['delta_time'] = df['timestamp'].diff().dt.total_seconds()

# Display the DataFrame
df
# Out:
#   phase               timestamp  \
# 0  INFO 2025-09-23 14:04:54.137
# 1    2a 2025-09-23 14:04:55.163
# 2    3a 2025-09-23 14:10:38.362
# 3    3b 2025-09-23 14:10:40.618
# 4    3c 2025-09-23 14:10:40.704
#
#                                                 note  delta_time
# 0          Pod initially scheduled to acnode11.e4red         NaN
# 1  kubelet/containerd stopped on acnode11.e4red v...       1.026
# 2  New pod test-app-5cbcc7d5f4-zx6ml scheduled on...     343.199
# 3    New pod entered Running phase on acnode10.e4red       2.256
# 4             New pod became Ready on acnode10.e4red       0.086

# %%
import pandas as pd


# Load the CSV file
df = pd.read_csv('node_failure_experiment-3.csv')
# convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# create new columns and put delta time in them from the previous row
df['delta_time'] = df['timestamp'].diff().dt.total_seconds()

# Display the DataFrame
df
# Out:
#   phase               timestamp  \
# 0  INFO 2025-09-23 14:13:49.353
# 1    2a 2025-09-23 14:13:49.498
# 2    3a 2025-09-23 14:19:39.235
# 3    3b 2025-09-23 14:19:40.366
# 4    3c 2025-09-23 14:19:40.435
#
#                                                 note  delta_time
# 0          Pod initially scheduled to acnode10.e4red         NaN
# 1  kubelet/containerd stopped locally on acnode10...       0.145
# 2  New pod test-app-5cbcc7d5f4-wz9h7 scheduled on...     349.737
# 3    New pod entered Running phase on acnode11.e4red       1.131
# 4             New pod became Ready on acnode11.e4red       0.069

# %%
import pandas as pd


# Load the CSV file
df = pd.read_csv('node_failure_experiment-4.csv')
# convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# create new columns and put delta time in them from the previous row
df['delta_time'] = df['timestamp'].diff().dt.total_seconds()

# Display the DataFrame
df
# Out:
#   phase               timestamp  \
# 0  INFO 2025-09-23 14:22:00.271
# 1    2a 2025-09-23 14:22:00.404
# 2    3a 2025-09-23 14:27:44.609
# 3    3b 2025-09-23 14:27:46.852
# 4    3c 2025-09-23 14:27:46.925
#
#                                                 note  delta_time
# 0          Pod initially scheduled to acnode10.e4red         NaN
# 1  kubelet/containerd stopped locally on acnode10...       0.133
# 2  New pod test-app-5cbcc7d5f4-tk5hx scheduled on...     344.205
# 3    New pod entered Running phase on acnode11.e4red       2.243
# 4             New pod became Ready on acnode11.e4red       0.073
